# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
dataset = pd.read_csv('daftar_gaji.csv', sep=',')
dataset
# Out:
#     Tahun_bekerja      Gaji
# 0             1.1   39343.0
# 1             1.3   46205.0
# 2             1.5   37731.0
# 3             2.0   43525.0
# 4             2.2   39891.0
# 5             2.9   56642.0
# 6             3.0   60150.0
# 7             3.2   54445.0
# 8             3.2   64445.0
# 9             3.7   57189.0
# 10            3.9   63218.0
# 11            4.0   55794.0
# 12            4.0   56957.0
# 13            4.1   57081.0
# 14            4.5   61111.0
# 15            4.9   67938.0
# 16            5.1   66029.0
# 17            5.3   83088.0
# 18            5.9   81363.0
# 19            6.0   93940.0
# 20            6.8   91738.0
# 21            7.1   98273.0
# 22            7.9  101302.0
# 23            8.2  113812.0
# 24            8.7  109431.0
# 25            9.0  105582.0
# 26            9.5  116969.0
# 27            9.6  112635.0
# 28           10.3  122391.0
# 29           10.5  121872.0

# %%
plt.scatter(data.Tahun_bekerja, data.Gaji)
plt.xlabel('Tahun Bekerja')  # Menggunakan xlabel
plt.ylabel('Gaji')           # Menggunakan ylabel
plt.title('Perbandingan Gaji Karyawan')
plt.show()

# %%
x = np.array(data.Tahun_bekerja)
y = np.array(data.Gaji)

x_train = x.reshape(-1,1)
y_train = y 

print(x)
print( x_train )
# Out:
# [ 1.1  1.3  1.5  2.   2.2  2.9  3.   3.2  3.2  3.7  3.9  4.   4.   4.1
#   4.5  4.9  5.1  5.3  5.9  6.   6.8  7.1  7.9  8.2  8.7  9.   9.5  9.6
#  10.3 10.5]
# [[ 1.1]
#  [ 1.3]
#  [ 1.5]
#  [ 2. ]
#  [ 2.2]
#  [ 2.9]
#  [ 3. ]
#  [ 3.2]
#  [ 3.2]
#  [ 3.7]
#  [ 3.9]
#  [ 4. ]
#  [ 4. ]
#  [ 4.1]
#  [ 4.5]
#  [ 4.9]
#  [ 5.1]
#  [ 5.3]
#  [ 5.9]
#  [ 6. ]
#  [ 6.8]
#  [ 7.1]
#  [ 7.9]
#  [ 8.2]
#  [ 8.7]
#  [ 9. ]
#  [ 9.5]
#  [ 9.6]
#  [10.3]
#  [10.5]]

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
plt.scatter (x_train, y_train, color='blue')
plt.plot(x_train, model.predict(x_train), color='red')
plt.xlabel('Tahun Bekerja')  # Menggunakan xlabel
plt.ylabel('Gaji')           # Menggunakan ylabel
plt.title('Perbandingan Gaji Karyawan')
plt.show()

# %%
x_test = np.array([150, 200, 169, 313, 346]).reshape(-1,1)
y_test = np.array([50, 31, 36, 100, 37])

prediksi_gaji = model.predict(x_test)
print(prediksi_gaji)
# Out:
# [1443286.54841693 1915784.66448968 1622835.83252458 2983630.40681411
#  3295479.16342212]

# %%
from sklearn.metrics import r2_score

r_square = r2_score(y_test, prediksi_gaji)
print(r_square)
# Out:
# -8733994002.654737
